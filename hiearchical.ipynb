# %%
import gensim.models
import gensim

# %%
dictionary = gensim.corpora.Dictionary.load('larry.dict')
corpus = gensim.corpora.MmCorpus('larry.mm')

hdp = gensim.models.hdpmodel.HdpModel(corpus, dictionary)
print hdp
# Out:
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# ...

# %%
hdp.print_topics(-1, topn=10)
# Out:
# [u'topic 0: 0.002*recommender + 0.002*mashed + 0.002*logic + 0.002*driven + 0.002*grading + 0.002*nutshell + 0.002*rstudio + 0.002*pocketcluster + 0.002*stich + 0.002*databasic',
#  u'topic 1: 0.003*data + 0.003*hybrid + 0.003*friends + 0.002*successful + 0.002*science + 0.002*quantitative + 0.002*typing + 0.002*essay + 0.002*note + 0.002*plug',
#  u'topic 2: 0.003*python + 0.003*hope + 0.002*string + 0.002*chaos + 0.002*using + 0.002*fuzzy + 0.002*logistic + 0.002*lessons + 0.002*run + 0.002*systems',
#  u'topic 3: 0.003*matrix + 0.002*computation + 0.002*optimize + 0.002*contain + 0.002*tokenizing + 0.002*wiatowski + 0.002*trips + 0.002*disqus + 0.002*ides + 0.002*layouts',
#  u'topic 4: 0.003*fellow + 0.003*used? + 0.002*cases + 0.002*jump + 0.002*degenerated + 0.002*used + 0.002*mcclementine + 0.002*addiction + 0.002*behemoths + 0.002*unfortunately',
# ...

# %%
hdp.optimal_ordering()
print "done"
# Out:
# done

# %%
hdp.print_topics(-1, topn=5)
# Out:
# [u'topic 0: 0.002*recommender + 0.002*mashed + 0.002*logic + 0.002*driven + 0.002*grading',
#  u'topic 1: 0.003*data + 0.003*hybrid + 0.003*friends + 0.002*successful + 0.002*science',
#  u'topic 2: 0.003*python + 0.003*hope + 0.002*string + 0.002*chaos + 0.002*using',
#  u'topic 3: 0.003*matrix + 0.002*computation + 0.002*optimize + 0.002*contain + 0.002*tokenizing',
#  u'topic 4: 0.003*fellow + 0.003*used? + 0.002*cases + 0.002*jump + 0.002*degenerated',
#  u'topic 5: 0.003*google + 0.003*time + 0.002*due + 0.002*post + 0.002*pandas',
#  u'topic 6: 0.002*paying + 0.002*12 + 0.002*maintenance + 0.002*transfer + 0.002*side',
#  u'topic 7: 0.003*phones + 0.002*descent + 0.002*top + 0.002*community + 0.002*flyelephant',
#  u'topic 8: 0.003*something + 0.002*follows + 0.002*correspondence + 0.002*happy + 0.002*logic',
#  u'topic 9: 0.003*dimensional + 0.003*sound + 0.003*data + 0.002*beast + 0.002*randalolson',
# ...
