# %%
import gensim.models
import gensim
from clean_data import load, clean

dictionary = gensim.corpora.Dictionary.load('larry.dict')
lsa = gensim.models.ldamodel.LdaModel.load('larry.lsa')

DATA = load('testing_data.p', 'excerpt')

for index, i in enumerate(DATA):
    print i
    doc = clean(i)
    doc_vec = dictionary.doc2bow(doc)
    lsa_vec = lsa[doc_vec]
    lsa_vec = sorted(lsa_vec, key=lambda x: x[1])
    print DATA[index], lda.print_topic(lsa_vec[-1][0]), '\n'
# Out:
# WARNING:root:failed to load state from larry.lsa.state: [Errno 2] No such file or directory: 'larry.lsa.state'
# Loading Data
# [u'Linear Algebra for Data Scientists It\u2019s important to know what goes on inside a machine learning algorithm. But it\u2019s hard. There is some pretty intense math happening, much of which\xa0is linear algebra. When I took Andrew Ng\u2019s course on machine learning, I found the hardest part was the linear algebra.', u'Building a Recommendation Engine for Reddit. Part 2 Step 2. Building the dataset On part 1 of this tutorial we laid out the project in detail, and decided that in order to calculate the similarity between two subs, we just need to find the list of users on each one.', u'How To Work Through A Problem Like A Data Scientist In a 2010 post Hilary Mason and Chris Wiggins described the OSEMN process as a taxonomy of tasks that a data scientist should feel comfortable working on.  The title of the post was \u201cA Taxonomy of Data Science\u201d on the now defunct dataists blog.', u'Machine Learning Please click on Timetables on the right hand side of this page for time and location of the practicals. The instructors are Brendan Shillingford and Marcin Moczulsky.  Practicals will use Torch, a powerful programming framework for deep learning that is very popular at Google and Facebook research.', u'The 7 Best Data Science and Machine Learning Podcasts Data science and machine learning have long been interests of mine, but now that I\u2019m working on Fuzzy.io I need to keep on top of all the news in both fields.  My preferred way to do this is through listening to podcasts.', u"DocSearch is live We\u2019ll get back to you within a few hours with everything you need to integrate your new search into your website.  Oh, and did we mention it's FREE? No commitment. No subscription. Everything is on us!", u"Level-Up Your Machine Learning What should I do if I want to get 'better' at machine learning, but I don't know what I want to learn?  Excellent question! My answer: consistently work your way through textbooks.", u"Visual design of SQLAlchemy models in 6 steps In this article I'm going to show you how to design SQLAlchemy models by using Vertabelo and our code generator. SQLAlchemy is propably the most advanced and well engineered OR/M for Python. Vertabelo is a database design tool that works in a web browser.", u'Building Analytics at Simple Early in 2014, Simple was a mid-stage startup with only a single analytics-focused employee. When we wanted to answer a question about customer behavior or business performance, we would have to query production databases.', u'Exceptional Logging of Exceptions in Python Aaron Maxwell is author of the Advanced Python Newsletter.  Exceptions happen. And as developers, we simply have to deal with them. Even when writing software to help us find burritos.', u'Implementing a CNN for Text Classification in TensorFlow \u2013 WildML The full code is available on Github.  In this post we will implement a model similar to Kim Yoon\u2019s Convolutional Neural Networks for Sentence Classification.', u'Tensor Methods in Machine Learning \u2013 Off the convex path Tensors are high dimensional generalizations of matrices.', u'The hardest parts of data science Contrary to common belief, the hardest part of data science isn\u2019t building an accurate model or obtaining good, clean data. It is much harder to define feasible problems and come up with reasonable ways of measuring solutions.', u'Implementing your own k-nearest neighbour algorithm using Python In machine learning, you may often wish to build predictors that allows to classify things into categories based on some set of associated values. For example, it is possible to provide a diagnosis to a patient based on data from previous patients.', u"Experimenting with AWS Machine Learning for Classification \u2013 Data Science Central In this post, I'll explore the new AWS Machine Learning services.  The problem we are trying to solve is to classify auto accident severity given a set of features. I'll not go into further details of the da ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c726b1c55d8c> in <module>()
#      10 for index, i in enumerate(DATA):
#      11     print i
# ---> 12     doc = clean(i)
#      13     doc_vec = dictionary.doc2bow(doc)
#      14     lsa_vec = lsa[doc_vec]
#
# /home/lwgray/pocket/clean_data.pyc in clean(data)
#      84     words <= 2 characters, and converting words to lowercase
#      85     '''
# ---> 86     words = re.sub("[^a-zA-Z]", " ", data)
#      87     words = words.lower().split()
#      88     words = [w for w in words if len(w) > 1]
#
# /home/lwgray/anaconda3/envs/topics/lib/python2.7/re.pyc in sub(pattern, repl, string, count, flags)
#     153     a callable, it's passed the match object and must return
#     154     a replacement string to be used."""
# --> 155     return _compile(pattern, flags).sub(repl, string, count)
#     156
#     157 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or buffer
